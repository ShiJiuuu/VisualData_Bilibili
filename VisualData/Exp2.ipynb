# %%
import matplotlib.pyplot as plt

#labels = ['童装', '奶粉辅食', '孕妈专区', '洗护喂养', '宝宝尿裤', '春夏新品', '童车童床', '玩具文娱', '童鞋']
labels = ['Clothing', 'Formula', 'Maternity', 'Care', 'Diapers', 'Seasonal', 'Gear', 'Toys', 'Shoes']
sales = [29665, 3135.4, 4292.4, 5240.9, 5543.4, 5633.8, 6414.5, 9308.1, 10353]

plt.figure(figsize=(7, 6))
plt.pie(sales, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Sales Revenue of Sub-categories on Pinduoduo Platform')
plt.axis('equal')
plt.tight_layout()
plt.show()
